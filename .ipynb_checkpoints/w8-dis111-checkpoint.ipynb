# %% [markdown]
# ## PS3 - W8 Discussion 111
#
# In this notebook, we will visit some data from from Arman Catterson's Psych 101 course, where they went over the psychological phenomenon of "anchoring." According to Wikipedia: "Anchoring is a cognitive bias whereby an individual's decisions are influenced by a particular reference point or anchor."
#
# In this case, students guessed the maximum speed of a house cat in miles per hour. In one condition, the "low" condition, students were prompted with the message
#
# "Is the maximum speed of an average house cat FASTER or SLOWER than **3** miles per hour?"
#
# In the other condition, the "high" condition, students were prompted with
#
# "Is the maximum speed of an average house cat FASTER or SLOWER than **40** miles per hour?"
#
# The student then had to provide an estimate for the speed of a house cat. We want to learn: did the anchoring have an effect on students' estimates? Let's assume that students were randomly assigned to each group.
#
# -------
#
# **Data Dictionary/Codebook**
#
# `cat`: estimated speed in mph
#
# `before`: 1 = student knew the exercise beforehand, 0 = student did not know
#
# `live.cats`: 1 = student lives with cats, 0 = student does not live with cats
#
# `cond`: 1 = student was exposed to the "high" condition (40 mph), 0 = student was exposed to the "low" condition (3 mph)

# %%
# Run this cell to read in the data.
anchor <- read.csv("./data/anchoring_data_FA20.csv")
head(anchor)
# Out:
#   cat before live.cats cond
# 1  2  0      0         0
# 2  1  0      0         1
# 3 30  0      0         1
# 4 25  0      0         1
# 5 17  0      0         0
# 6 50  0      0         1

# %% [markdown]
# ### Quick Check 1:
#
# Compute the difference in means between the high condition and low condition.

# %%
# Type your code here
library(estimatr)
difference_in_means(cat~cond, anchor, condition1=0, condition2=1)
# Out:
# Design:  Standard
#      Estimate Std. Error  t value     Pr(>|t|) CI Lower CI Upper       DF
# cond 18.75946   2.757204 6.803798 8.612699e-10 13.28673 24.23218 96.38872

# %% [markdown]
# ### Quick Check 2:
#
# Interpret the confidence interval you obtained above

# %% [markdown]
# **Solution:** there is a 95% chance that (13.29, 24.23) captures the true treatment effect

# %% [markdown]
# ### Quick Check 3:
#
# What is the treatment effect among those who live with cats?

# %%
# Type your code here
anchor_live_with_cats <- subset(anchor, live.cats == 1)
difference_in_means(cat~cond, anchor_live_with_cats, condition1=0, condition2=1)
# Out:
# Design:  Standard
#      Estimate Std. Error  t value    Pr(>|t|) CI Lower CI Upper       DF
# cond 22.04885   6.620457 3.330412 0.002367054 8.510253 35.58745 29.08695

# %% [markdown]
# ### Quick Check 4:
#
# What is the treatment effect among those who do not live with cats?

# %%
# Type your code here
anchor_not_live_with_cats <- subset(anchor, live.cats == 0)
difference_in_means(cat~cond, anchor_not_live_with_cats, condition1=0, condition2=1)
# Out:
# Design:  Standard
#      Estimate Std. Error t value     Pr(>|t|) CI Lower CI Upper       DF
# cond 16.96897   2.296552 7.38889 1.092557e-10 12.40074  21.5372 82.41654

# %% [markdown]
# ### Quick Check 5:
#
# Evaluate the following claim: 'since the treatment effect among those who live with cats is greater than those who don't, living with cats causes participants to be more receptive to the treatment.' Explain.

# %% [markdown]
# **Solution:** the claim is false. Even though the treatment effect is greater among those who live with cats is greater than those who don't, we cannot say living with cats *causes* a larger treatment effect. For example, those older are more likely to live with cats, and those older have a larger treatment effect

# %% [markdown]
# ### Quick Check 6:
#
# The experiment here is trying to show how a particular reference point can affect individuals' decision making process. Can you think of challenges to its external validity?

# %% [markdown]
# **Solution:** open-ended question. Example: is the speed of a cat a good treatment to generalize to how people make more important decisions? For example, would anchoring on people's expectations on income have similar effects?

# %% [markdown]
# In the cell below, we create some 'precision' variable in our data. For the sake of argument, take that as the weight of the observations.

# %%
# Run this cell
anchor$precision <- runif(151)
# How it looks like now?
head(anchor)
# Out:
#   cat before live.cats cond precision
# 1  2  0      0         0    0.8047493
# 2  1  0      0         1    0.1930881
# 3 30  0      0         1    0.6257376
# 4 25  0      0         1    0.8729650
# 5 17  0      0         0    0.3347713
# 6 50  0      0         1    0.1820316

# %% [markdown]
# ### Quick Check 7:
#
# Compute the weighed average of the guesses (`cat` weighed by `precision`)

# %%
# Type your code here
weighted.mean(anchor$cat, anchor$precision)
# Out:
# [1] 19.68357
